# %% [markdown]
# # Silver Layer – Cleansed & Modeled Tables

# %%
df_sup = spark.table("PharmaLakehouse.bronze_suppliers")
display(df_sup)
# Out:
# StatementMeta(, 11379b82-c70c-4c81-b7ee-5429a9f43377, 9, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 616c0d23-ef08-4e56-9045-d8306e47fe3a)

# %%
from pyspark.sql.functions import *
from pyspark.sql import *

df_sup = df_sup.dropDuplicates(["supplier_id"])
display(df_sup)
# Out:
# StatementMeta(, 11379b82-c70c-4c81-b7ee-5429a9f43377, 11, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 9b5e0da6-25f7-4d7b-8484-a7d122165241)

# %%
df_sup.write.format("delta").mode("overwrite").saveAsTable("silver_suppliers")
# Out:
# StatementMeta(, 11379b82-c70c-4c81-b7ee-5429a9f43377, 16, Finished, Available, Finished)

# %% [markdown]
# # ORDERS TABLE

# %%
df_orders = spark.table("PharmaLakehouse.bronze_raw_orders")
display(df_orders)
# Out:
# StatementMeta(, 11379b82-c70c-4c81-b7ee-5429a9f43377, 17, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 430d7c3a-9137-44fd-8281-c4518b8d17b6)

# %%
df_orders = df_orders.dropDuplicates(["order_id"])
display(df_orders)
# Out:
# StatementMeta(, 11379b82-c70c-4c81-b7ee-5429a9f43377, 18, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 4ed2c545-ab87-458d-99b2-ec6335fbd15d)

# %%
df_orders = df_orders.dropna(subset=["order_id","material"])
display(df_orders)
# Out:
# StatementMeta(, 11379b82-c70c-4c81-b7ee-5429a9f43377, 19, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 3313f5e7-0fde-4884-a6e4-2b01557ad0c2)

# %%
df_orders.write.format("delta").mode("overwrite").saveAsTable("silver_orders")
# Out:
# StatementMeta(, 11379b82-c70c-4c81-b7ee-5429a9f43377, 20, Finished, Available, Finished)

# %% [markdown]
# #

# %%
df_prod = spark.table("PharmaLakehouse.bronze_production_logs")
display(df_prod)
# Out:
# StatementMeta(, 11379b82-c70c-4c81-b7ee-5429a9f43377, 21, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 2be8eb5f-993c-4f80-82c2-19c6f729a31e)

# %%
df_prod= df_prod.dropna(subset=["batch_id", "product_id"]).dropDuplicates(["batch_id"])
display(df_prod)
# Out:
# StatementMeta(, 11379b82-c70c-4c81-b7ee-5429a9f43377, 23, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, abc73fb6-692d-42b8-8c04-b4be7a01e4b0)

# %%
df_prod.write.format("delta").mode("overwrite").saveAsTable("silver_prodction")
# Out:
# StatementMeta(, 11379b82-c70c-4c81-b7ee-5429a9f43377, 24, Finished, Available, Finished)

# %%
df_inv = spark.table("PharmaLakehouse.bronze_inventory")
display(df_inv)
# Out:
# StatementMeta(, 11379b82-c70c-4c81-b7ee-5429a9f43377, 25, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 999cc173-83a5-44af-a343-754447dc4574)

# %%
df_inv = df_inv.dropna(subset=["warehouse_id","product_id"])
df_inv.write.format("delta").mode("overwrite").saveAsTable("silver_inventory")
# Out:
# StatementMeta(, 11379b82-c70c-4c81-b7ee-5429a9f43377, 26, Finished, Available, Finished)

# %%
df_sales = spark.table("PharmaLakehouse.bronze_sales")
display(df_sales)
# Out:
# StatementMeta(, 11379b82-c70c-4c81-b7ee-5429a9f43377, 27, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, bcf9b301-7b72-4e64-8900-1f813ecf3be7)

# %%
df_sales = df_sales.dropna(subset=["region","product_id"])
df_sales.write.format("delta").mode("overwrite").saveAsTable("silver_sales")
# Out:
# StatementMeta(, 11379b82-c70c-4c81-b7ee-5429a9f43377, 28, Finished, Available, Finished)

# %%
df_iot = spark.table("PharmaLakehouse.bronze_iot_logs")
display(df_iot)
# Out:
# StatementMeta(, 11379b82-c70c-4c81-b7ee-5429a9f43377, 29, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 948f0b24-8e6a-4032-9d7c-9bd8c2fd867d)

# %%
df_iot.write.format("delta").mode("overwrite").saveAsTable("silver_iot_metrics")
# Out:
# StatementMeta(, 11379b82-c70c-4c81-b7ee-5429a9f43377, 30, Finished, Available, Finished)

# %%
df_qc = spark.table("PharmaLakehouse.bronze_qc_reports")
display(df_qc)
# Out:
# StatementMeta(, 11379b82-c70c-4c81-b7ee-5429a9f43377, 31, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, d6bb033e-1b17-484b-8d5d-dd2e5ebcdac6)

# %%
df_qc.write.format("delta").mode("overwrite").saveAsTable("silver_qc_reports")
# Out:
# StatementMeta(, 11379b82-c70c-4c81-b7ee-5429a9f43377, 32, Finished, Available, Finished)
